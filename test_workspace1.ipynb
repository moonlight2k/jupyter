# %% [markdown]
# # Opening a file
#
# In the code below, I:
#  - opened the file with the `open()` command
#  - read the file with the `read()` command
#  - converted the read file into a list with the `list()` command

# %% [markdown]
# The `AppleStore.csv` dataset is a compilation of the details of 7000+ apps in the app store.
# It was gotten from the Apple appstore.
# Click on the [Link](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps) to download the file.

# %% [markdown]
# | Column name | Description |
# | ----------- | ----------- |
# | Id | App Id |
# | track_name | App Name |
# | size_bytes | Size (in Bytes) |

# %%
file = open('AppleStore.csv')
from csv import reader
read_file = reader(file)
# list_file = list(read_file)

# %%
def welcome(a_string):
    print('welcome to ' + a_string + '!')
dq = 'database'
jn = 'jupyter notebook'
py = 'python'

# %%
welcome(dq)
welcome(jn)
welcome(py)

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line after each row

    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))
